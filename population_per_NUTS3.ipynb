# %%
import pandas as pd

# %%
# Read data
data = pd.read_csv('/Users/maijahavusela/Desktop/gradu/data/population_NUTS3_2021.csv',sep=',')

# Choose wanted columns
data = data[['geo','TIME_PERIOD','OBS_VALUE']]

# Clean column names
data['NUTS_CODE'] = data['geo'].str.split(':').str[0]
data['NUTS_NAME'] = data['geo'].str.split(':').str[-1]

# Renaming columns
data.rename(columns={"OBS_VALUE": "POP"}, inplace=True)
data = data[['NUTS_CODE','NUTS_NAME','POP','TIME_PERIOD']]
data
# Out:
#                      DATAFLOW        LAST UPDATE      freq      sex  \
# 0  ESTAT:DEMO_R_PJANGRP3(1.0)  13/03/25 23:00:00  A:Annual  T:Total
# 1  ESTAT:DEMO_R_PJANGRP3(1.0)  13/03/25 23:00:00  A:Annual  T:Total
# 2  ESTAT:DEMO_R_PJANGRP3(1.0)  13/03/25 23:00:00  A:Annual  T:Total
# 3  ESTAT:DEMO_R_PJANGRP3(1.0)  13/03/25 23:00:00  A:Annual  T:Total
# 4  ESTAT:DEMO_R_PJANGRP3(1.0)  13/03/25 23:00:00  A:Annual  T:Total
#
#         unit          age            geo  TIME_PERIOD  OBS_VALUE OBS_FLAG  \
# 0  NR:Number  TOTAL:Total    AL011:Dibër         2021     113683      NaN
# 1  NR:Number  TOTAL:Total   AL012:Durrës         2021     292029      NaN
# 2  NR:Number  TOTAL:Total    AL013:Kukës         2021      74388      NaN
# 3  NR:Number  TOTAL:Total    AL014:Lezhë         2021     120678      NaN
# 4  NR:Number  TOTAL:Total  AL015:Shkodër         2021     197177      NaN
#
#    CONF_STATUS
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# Save data
#data.to_csv('/Users/maijahavusela/Desktop/gradu/data/pythonista/NUTS3_population_2021.csv')

# %% [markdown]
# ## Aggregating to area (square kilometers)

# %%
# Read data
data2 = pd.read_csv('/Users/maijahavusela/Desktop/gradu/data/area_NUTS3.csv',sep=',')

# Choose wanted columns
data2 = data2[['geo','TIME_PERIOD','OBS_VALUE']]

# Renaming columns
data2.rename(columns={"OBS_VALUE": "AREA", "geo":"NUTS_NAME"}, inplace=True)
data2.head()
# Out:
#   NUTS_NAME  TIME_PERIOD    AREA
# 0     Dibër         2024  1661.0
# 1    Durrës         2024  3528.0
# 2     Kukës         2024  2469.0
# 3     Lezhë         2024  2392.0
# 4   Shkodër         2024   770.0

# %%
# Normalizing names
data2["NUTS_NAME"] = data2["NUTS_NAME"].str.strip().str.lower()
data["NUTS_NAME"] = data["NUTS_NAME"].str.strip().str.lower()

# Aggregating the population dataframe with the area dataframe
df_merged = data2.merge(data, left_on="NUTS_NAME", right_on="NUTS_NAME", how="left")
df_merged
# Out:
#              NUTS_NAME  TIME_PERIOD_x    AREA NUTS_CODE       POP  \
# 0                dibër           2024  1661.0     AL011  113683.0
# 1               durrës           2024  3528.0     AL012  292029.0
# 2                kukës           2024  2469.0     AL013   74388.0
# 3                lezhë           2024  2392.0     AL014  120678.0
# 4              shkodër           2024   770.0     AL015  197177.0
# ...                ...            ...     ...       ...       ...
# 1771          pejë/peć           2024  1660.0       NaN       NaN
# 1772   prizren/prizren           2024  1433.0       NaN       NaN
# 1773  ferizaj/uroševac           2024  1021.0       NaN       NaN
# 1774   gjilan/gnjilane           2024  1412.0       NaN       NaN
# 1775  gjakovë/đakovica           2024  1247.0       NaN       NaN
#
#       TIME_PERIOD_y
# 0            2021.0
# 1            2021.0
# 2            2021.0
# 3            2021.0
# 4            2021.0
# ...             ...
# 1771            NaN
# 1772            NaN
# 1773            NaN
# 1774            NaN
# 1775            NaN
#
# [1776 rows x 6 columns]
